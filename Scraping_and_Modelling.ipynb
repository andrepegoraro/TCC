# %% [markdown]
# <a href="https://colab.research.google.com/github/andrepegoraro/TCC/blob/main/Scraping_and_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Monografia

# %% [markdown]
# ## Introdução

# %% [markdown]
# Escrever Intro

# %% [markdown]
# ### API's

# %%
import requests

headers = {
    'accept': '*/*',
    'accept-language': 'pt-BR,pt;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cache-control': 'max-age=0',
    # 'cookie': '_gcl_au=1.1.152233211.1718504735; _ga=GA1.1.1723711130.1718504736; _fbp=fb.1.1718505419074.77313328481786846; _ga_47RNFYWRSH=GS1.1.1718647956.5.0.1718647956.0.0.0; _lr_env_src_ats=false; cto_bundle=_2ZN9l80NkdlUGQ1anJzTEliaFQ0WnVCNmFQc085SEhHQWsycEdYcEdCU25ab0VNMCUyRk9sZGlkSFVLJTJGVG1NYVlldWxrTWJvUTB2S2NVbm1sJTJGek5PR2IyOGtzZklyWGdqNTg4T215QmtVcnE1S0tQSHdEWUdsWHpYU1ZJNjklMkZ0YnRyYTVScUtVaDJmUVRVM0RYNXdsRnBCS09xQSUzRCUzRA; _lr_retry_request=true; __browsiSessionID=7ba2de1b-270d-4a94-b393-dc0e2c2c33ef&false&DEFAULT&ar&desktop-4.26.13&false; __browsiUID=01927aa6-818a-4291-8e12-b1f0925c5ec7; FCNEC=%5B%5B%22AKsRol-R4liUbXTLO0JaZ63R4SBxY6a0iw-5DkFPnALLQHkylKAY2HGnNqLMfA5cOi2-HklMzONbeap1lEF5k9QNzjjID8A_XCIbdXUMNJ7Xi7_8kWIKq4GCmJt0u7560wu1N0T_WJlbbBh_rl9MBpUIsX_4OGgC1g%3D%3D%22%5D%5D; __gads=ID=4a2fefaf83e77afa:T=1718504738:RT=1721743845:S=ALNI_Ma9io9Qt-PTo3DSGbv6kGB46s-hGA; __gpi=UID=00000a2e19db15f5:T=1718504738:RT=1721743845:S=ALNI_MZmhLj9Z7rHs-gmWdyjOSDg7jSXng; __eoi=ID=2a8a0003bed316dd:T=1718504738:RT=1721743845:S=AA-AfjZXwVYmpt7rmhmkJIW8PewF; _ga_HNQ9P9MGZR=GS1.1.1721742334.6.1.1721743846.46.0.0; _ga_QH2YGS7BB4=GS1.1.1721742333.6.1.1721744192.0.0.0; _ga_3KF4XTPHC4=GS1.1.1721742333.6.1.1721744192.60.0.0',
    'dnt': '1',
    'if-none-match': 'W/"5037e07a01"',
    'priority': 'u=1, i',
    # 'referer': 'https://www.sofascore.com/football/match/internacional-corinthians/hOsqO',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Microsoft Edge";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0',
    'x-requested-with': 'aa3411',
}

response = requests.get('https://www.sofascore.com/api/v1/event/10114146/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## Web Scraping 2.0

# %%
headers['If-Modified-Since'] = 'Tue, 23 Jul 2024 00:00:00 GMT'

# %%
response = requests.get('https://www.sofascore.com/api/v1/event/12117064/shotmap', headers=headers)
response.status_code
# Out:
# 200

# %%
import requests

# Definição dos cabeçalhos sem cabeçalhos de cache
headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'pragma': 'no-cache',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"',
    'sec-ch-ua-mobile': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'x-sofa-api-version': '1.0',
}

response = requests.get('https://www.sofascore.com/api/v1/event/10113705/shotmap', headers=headers)

response.status_code
# Out:
# 200

# %%
data = response.json()

# %% [markdown]
# #### Data First Version

# %%
data
# Out:
# {'shotmap': [{'player': {'name': 'Caio Paulista',
#     'slug': 'caio-paulista',
#     'shortName': 'C. Paulista',
#     'position': 'D',
#     'jerseyNumber': '16',
#     'userCount': 1366,
#     'id': 931591},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 18.8, 'y': 52.7, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 54.1, 'z': 66.7},
#    'xg': 0.073947429656982,
#    'id': 1144185,
#    'time': 90,
#    'addedTime': 3,
#    'timeSeconds': 5565,
#    'draw': {'start': {'x': 52.7, 'y': 18.8},
#     'end': {'x': 45.9, 'y': 0},
#     'goal': {'x': 45.9, 'y': 33.3}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 735,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Pablo Maia',
#     'firstName': 'Pablo Maia',
#     'lastName': '',
#     'slug': 'pablo-maia',
#     'shortName': 'P. Maia',
#     'position': 'M',
# ...

# %% [markdown]
# ### Extract JSON

# %%
import pandas as pd

shots = []
for shot in data['shotmap']:
    shot_info = {
        'player_name': shot['player']['name'],
        'player_position': shot['player'].get('position', ''),
        'player_jersey_number': shot['player'].get('jerseyNumber', ''),
        'player_id': shot['player']['id'],
        'is_home': shot['isHome'],
        'shot_type': shot['shotType'],
        'situation': shot['situation'],
        'player_x': shot['playerCoordinates']['x'],
        'player_y': shot['playerCoordinates']['y'],
        'player_z': shot['playerCoordinates'].get('z', 0),
        'body_part': shot['bodyPart'],
        'goal_mouth_location': shot['goalMouthLocation'],
        'goal_mouth_x': shot['goalMouthCoordinates']['x'],
        'goal_mouth_y': shot['goalMouthCoordinates']['y'],
        'goal_mouth_z': shot['goalMouthCoordinates']['z'],
        'xg': shot['xg'],
        'shot_id': shot['id'],
        'time': shot['time'],
        'added_time': shot.get('addedTime', 0),
        'time_seconds': shot['timeSeconds'],
        'incident_type': shot['incidentType']
    }
    shots.append(shot_info)

# DataFrame convert
df = pd.DataFrame(shots)

# DataFrame exibition
print(df.head(10))
# Out:
#      player_name player_position player_jersey_number  player_id  is_home  \
# 0  Caio Paulista               D                   16     931591    False
# 1     Pablo Maia               M                   29    1120721     True
# 2    Germán Cano               F                   14      33238    False
# 3          André               M                    7    1035996    False
# 4         Nathan               M                   14     358538    False
# 5    Germán Cano               F                   14      33238    False
# 6         Nathan               M                   14     358538    False
# 7         Nathan               M                   14     358538    False
# 8         Manoel               D                   26      84845    False
# 9         Nathan               M                   14     358538    False
#
#   shot_type  situation  player_x  player_y  player_z  ... goal_mouth_location  \
# ...

# %%
df.info()

# %% [markdown]
# ## Primeira rodada do Brasileirão 2022

# %% [markdown]
# ### Santos x Fluminense

# %%
# Fazendo Request da API
response_11 = requests.get('https://www.sofascore.com/api/v1/event/10114032/shotmap', headers=headers)
response_11.status_code
# Out:
# 200

# %%
data_11 = response_11.json()
data_11
# Out:
# {'shotmap': [{'player': {'name': 'Valdívia',
#     'slug': 'valdivia',
#     'shortName': 'Valdívia',
#     'position': 'M',
#     'jerseyNumber': '10',
#     'userCount': 156,
#     'id': 356522},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 21.2, 'y': 60.9, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 52.9, 'z': 77.8},
#    'xg': 0.037116527557373,
#    'id': 1150027,
#    'time': 90,
#    'addedTime': 6,
#    'timeSeconds': 5753,
#    'draw': {'start': {'x': 60.9, 'y': 21.2},
#     'end': {'x': 47.1, 'y': 0},
#     'goal': {'x': 47.1, 'y': 22.2}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 547,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Matheus Vargas',
#     'slug': 'vargas-matheus',
#     'shortName': 'M. Vargas',
#     'position': 'M',
#     'jerseyNumber': '96',
#     'userCount': 80,
#     'id': 811310},
# ...

# %%
shots_11 = []
for shot in data_11['shotmap']:
    shot_info = {
        'player_name': shot['player']['name'],
        'player_position': shot['player'].get('position', ''),
        'player_jersey_number': shot['player'].get('jerseyNumber', ''),
        'player_id': shot['player']['id'],
        'is_home': shot['isHome'],
        'shot_type': shot['shotType'],
        'situation': shot['situation'],
        'player_x': shot['playerCoordinates']['x'],
        'player_y': shot['playerCoordinates']['y'],
        'player_z': shot['playerCoordinates'].get('z', 0),
        'body_part': shot['bodyPart'],
        'goal_mouth_location': shot['goalMouthLocation'],
        'goal_mouth_x': shot['goalMouthCoordinates']['x'],
        'goal_mouth_y': shot['goalMouthCoordinates']['y'],
        'goal_mouth_z': shot['goalMouthCoordinates']['z'],
        'xg': shot['xg'],
        'shot_id': shot['id'],
        'time': shot['time'],
        'added_time': shot.get('addedTime', 0),
        'time_seconds': shot['timeSeconds'],
        'incident_type': shot['incidentType']
    }
    shots_11.append(shot_info)

# DataFrame convert
df_11 = pd.DataFrame(shots_11)

# DataFrame exibition
print(df_11.head(10))
# Out:
#       player_name player_position player_jersey_number  player_id  is_home  \
# 0        Valdívia               M                   10     356522     True
# 1  Matheus Vargas               M                   96     811310    False
# 2            Pepê               M                   23     946945     True
# 3      André Luís               F                   97     876286     True
# 4         Alesson               M                   11     871015     True
# 5        Valdívia               M                   10     356522     True
# 6         Joaquim               D                    2    1047740     True
# 7     Rodriguinho               M                          797939     True
# 8        Valdívia               M                   10     356522     True
# 9   Kelvin Osorio               M                   33     818997     True
#
#   shot_type  situation  player_x  player_y  player_z  ... goal_mouth_location  \
# ...

# %% [markdown]
# ### Atletico Goianiense x Flamengo

# %%
# Fazendo Request da API
response_1_2 = requests.get('https://www.sofascore.com/api/v1/event/10114121/shotmap', headers=headers)
response_1_2.status_code

# Convertendo o JSON da Response em um conjunto de dados
data_1_2 = response_1_2.json()
data_1_2

# Convertendo os dados JSON em um DataFrame
shots_1_2 = []
for shot in data_1_2['shotmap']:
    shot_info = {
        'player_name': shot['player']['name'],
        'player_position': shot['player'].get('position', ''),
        'player_jersey_number': shot['player'].get('jerseyNumber', ''),
        'player_id': shot['player']['id'],
        'is_home': shot['isHome'],
        'shot_type': shot['shotType'],
        'situation': shot['situation'],
        'player_x': shot['playerCoordinates']['x'],
        'player_y': shot['playerCoordinates']['y'],
        'player_z': shot['playerCoordinates'].get('z', 0),
        'body_part': shot['bodyPart'],
        'goal_mouth_location': shot['goalMouthLocation'],
        'goal_mouth_x': shot['goalMouthCoordinates']['x'],
        'goal_mouth_y': shot['goalMouthCoordinates']['y'],
        'goal_mouth_z': shot['goalMouthCoordinates']['z'],
        'xg': shot['xg'],
        'shot_id': shot['id'],
        'time': shot['time'],
        'added_time': shot.get('addedTime', 0),
        'time_seconds': shot['timeSeconds'],
        'incident_type': shot['incidentType']
    }
    shots_1_2.append(shot_info)

# DataFrame convert
df_1_2 = pd.DataFrame(shots_1_2)

# DataFrame exibition
print(df_1_2.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-213b8bf11d90> in <cell line: 2>()
#       1 # Fazendo Request da API
# ----> 2 response_1_2 = requests.get('https://www.sofascore.com/api/v1/event/10114121/shotmap', headers=headers)
#       3 response_1_2.status_code
#       4
#       5 # Convertendo o JSON da Response em um conjunto de dados
#
# NameError: name 'requests' is not defined

# %% [markdown]
# ## Automatizando o Código

# %%
import re

# Path to the uploaded text file
file_path = 'brasileirao_2022_scraping.txt'

# Function to extract all IDs and format the new URLs
def extract_and_format_urls(file_path):
    formatted_links = []
    with open(file_path, 'r') as file:
        content = file.read()
        # Find all the matches for id: followed by the event number
        ids = re.findall(r'#id:(\d+)', content)
        # Format each id into the desired URL format
        formatted_links = [f"https://www.sofascore.com/api/v1/event/{event_id}/shotmap" for event_id in ids]
    return formatted_links

# Get the formatted URLs
formatted_links = extract_and_format_urls(file_path)

# Show the result
formatted_links
# Out:
# ['https://www.sofascore.com/api/v1/event/10113678/shotmap',
#  'https://www.sofascore.com/api/v1/event/10114121/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113769/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113772/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113936/shotmap',
#  'https://www.sofascore.com/api/v1/event/10114016/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113771/shotmap',
#  'https://www.sofascore.com/api/v1/event/10114108/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113978/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113910/shotmap',
#  'https://www.sofascore.com/api/v1/event/10114032/shotmap',
#  'https://www.sofascore.com/api/v1/event/10114079/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113957/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113748/shotmap',
#  'https://www.sofascore.com/api/v1/event/10113993/shotmap',
#  'https://www.sofascore.com/api/v1/event/10114134/shotmap',
# ...

# %%
import requests
import pandas as pd

# Definição dos cabeçalhos sem cabeçalhos de cache
headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'pragma': 'no-cache',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"',
    'sec-ch-ua-mobile': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'x-sofa-api-version': '1.0',
}

# Lista de URLs
urls = formatted_links

# Lista para armazenar todos os dados de chutes
all_shots = []

# Loop para iterar sobre cada URL
for url in urls:
    response = requests.get(url, headers=headers)

    # Verificar se a requisição foi bem-sucedida
    if response.status_code == 200:
        data = response.json()

        # Extrair os dados dos chutes e armazenar
        for shot in data['shotmap']:
            shot_info = {
                'event_id': url.split('/')[-2],  # Adiciona o ID do evento para referência
                'player_name': shot['player']['name'],
                'player_position': shot['player'].get('position', ''),
                'player_jersey_number': shot['player'].get('jerseyNumber', ''),
                'player_id': shot['player']['id'],
                'is_home': shot['isHome'],
                'shot_type': shot['shotType'],
                'situation': shot['situation'],
                'player_x': shot['playerCoordinates']['x'],
                'player_y': shot['playerCoordinates']['y'],
                'player_z': shot['playerCoordinates'].get('z', 0),
                'body_part': shot['bodyPart'],
                'goal_mouth_location': shot['goalMouthLocation'],
                'goal_mouth_x': shot['goalMouthCoordinates']['x'],
                'goal_mouth_y': shot['goalMouthCoordinates']['y'],
                'goal_mouth_z': shot['goalMouthCoordinates']['z'],
                'xg': shot.get('xg', None),
                'shot_id': shot['id'],
                'time': shot['time'],
                'added_time': shot.get('addedTime', 0),
                'time_seconds': shot['timeSeconds'],
                'incident_type': shot['incidentType']
            }
            all_shots.append(shot_info)
    else:
        print(f"Erro na requisição para {url}: {response.status_code}")

# Convertendo todos os dados de chutes para um DataFrame
dataframe = pd.DataFrame(all_shots)

# Exibindo os primeiros 10 registros
print(dataframe.head(10))
dataframe.info()
# Out:
# Erro na requisição para https://www.sofascore.com/api/v1/event/10114000/shotmap: 404
# Erro na requisição para https://www.sofascore.com/api/v1/event/10113966/shotmap: 404
#    event_id    player_name player_position player_jersey_number  player_id  \
# 0  10113678           Fred               F                           12764
# 1  10113678           Fred               F                           12764
# 2  10113678           Fred               F                           12764
# 3  10113678  Luiz Henrique               M                    7    1035995
# 4  10113678      Cristiano               D                   12     886239
# 5  10113678     Jhon Arias               M                   21     844096
# 6  10113678    Germán Cano               F                   14      33238
# 7  10113678         Nonato               M                   16     922566
# 8  10113678         Nonato               M                   16     922566
# ...

# %%
distinct_name_count = dataframe.event_id.nunique()
print("Número de jogos distintos:", distinct_name_count)
# Out:
# Número de jogos distintos: 380

# %% [markdown]
# ## Exploratory Data Analysis
#
# The first impression had here is that the grain of the table is an incident. In this case, the incident is always gonna be a shot, because that is what matters for us to build a Expected Goals (xG) model.

# %% [markdown]
# ### Total Shots Analysis

# %% [markdown]
# #### Total Shots by Player Position

# %%
shots_per_position = dataframe.groupby('player_position').size().reset_index(name='total_shots')
shots_per_position
# Out:
#   player_position  total_shots
# 0               D         1953
# 1               F         3393
# 2               G            2
# 3               M         5007
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# shots_per_position['total_shots'].plot(kind='hist', bins=20, title='total_shots')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# shots_per_position.groupby('player_position').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %% [markdown]
# #### Total de Finalizações por Tipo

# %%
shots_by_type = dataframe.groupby('shot_type').size().reset_index(name='total_shots')
shots_by_type
# Out:
#   shot_type  total_shots
# 0     block         2683
# 1      goal          905
# 2      miss         4178
# 3      post          180
# 4      save         2409
